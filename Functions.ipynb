# %% [markdown]
# <a href="https://colab.research.google.com/github/amitheb/Amitheb21/blob/main/Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img = cv.imread("/content/8925d1a9596b69c57bbe1cb4e53ce206.jpg",-1)
image = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
print (image)
a = img.shape
print(a)
plt.imshow(image, cmap="gray")
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))
#Specify the data type so that
#float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)
invlog_image = (np.exp(image/c))-1
invlog_image = np.array(invlog_image, dtype=np.uint8)
invlog_image = (np.exp(image/c))-1
# Specify the data type..
invlog_image = np.array(invlog_image, dtype=np.uint8)
# Display both images 
plt.imshow(image,cmap='gray')
plt.show()
plt. imshow(log_image, cmap='gray')
plt.show()
plt.imshow(invlog_image, cmap='gray')
plt.show()
hist = cv.calcHist([image], [0], None, [256],[0, 256])
plt.plot(hist)
# Out:
# [[ 78  78  77 ...  32  29  29]
#  [ 79  78  78 ...  30  29  29]
#  [ 78  78  77 ...  27  28  28]
#  ...
#  [192 190 187 ... 185 178 178]
#  [181 180 179 ... 197 187 182]
#  [181 180 179 ... 197 187 182]]
# (1106, 850, 3)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log
#   # This is added back by InteractiveShellApp.init_path()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
img=cv.imread('/content/8925d1a9596b69c57bbe1cb4e53ce206.jpg',-1)
img=cv.cvtColor(img, cv.COLOR_BGR2GRAY)
print(img)
a=img.shape
print(a)
plt.imshow(img,cmap='gray')
gamma_val1=0.2
gamma_val2=0.5 
gamma_val3=1.4
gamma_val4=2.2
# Apply per-element exponentiation using the specifie
gamma_corrected1=np.power(img,gamma_val1) 
gamma_corrected2=np.power(img,gamma_val2)
gamma_corrected3=np.power(img,gamma_val3) 
gamma_corrected4=np.power(img,gamma_val4)
plt.imshow(img, cmap='gray')
plt.show()
plt.imshow(gamma_corrected1, cmap='gray')
plt.show()
plt.imshow(gamma_corrected2, cmap='gray')
plt.show()
plt.imshow(gamma_corrected3, cmap='gray')
plt.show()
plt.imshow(gamma_corrected4, cmap='gray')
plt.show()
# Out:
# [[ 78  78  77 ...  32  29  29]
#  [ 79  78  78 ...  30  29  29]
#  [ 78  78  77 ...  27  28  28]
#  ...
#  [192 190 187 ... 185 178 178]
#  [181 180 179 ... 197 187 182]
#  [181 180 179 ... 197 187 182]]
# (1106, 850)
